# %%
class Config():
    def __init__(self):
        self.base_dir_data = spark.sql("DESCRIBE EXTERNAL LOCATION `data_zone`").select("url").collect()[0][0]
        self.base_dir_checkpoint = spark.sql("DESCRIBE EXTERNAL LOCATION `chkpt_zone`").select("url").collect()[0][0]
        self.bronze_db = "sbit_bronze"
        self.silver_db = "sbit_silver"
        self.gold_db = "sbit_gold"
        self.maxFilesPerTrigger = 1000
        print(self.base_dir_data)
        print(self.base_dir_checkpoint)

config = Config()
